# %% [markdown]
# # 差分
#
# - 差分定义: diff[i] = a[i] - a[i-1]
# - 对差分数组做`前缀和`可以`还原`数组
#
# 利用差分给区间上的所有元素 +x
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# - (x1,y1) -> (x2, y2) 增加 x
#   - diff[x1][y1] += x
#   - diff[x1][y2 + 1] -= x
#   - diff[x2][y1] -= x
#   - diff[x2 + 1][y2 + 1] += x <补回来的数>
